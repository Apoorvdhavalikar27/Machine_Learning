# %%
# SVM : Support vector classifier

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("DataSets/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.0
# 1      2            4.9           3.0            1.4           NaN
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df[0:50]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.0  Iris-setosa
# 1    2            4.9           3.0            1.4           NaN  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.fillna(0,inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Species']  = le.fit_transform(df.Species)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.0        0
# 1      2            4.9           3.0            1.4           0.0        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
X = df.drop(columns = ['Id','Species'])
X.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.0
# 1            4.9           3.0            1.4           0.0
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y = df.Species

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.svm import SVC
clf = SVC()
clf.fit(X_train,y_train)
# Out:
# SVC()

# %%
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
df1 = df[0:50]
df2 = df[50:100]
df3 = df[100:150]

# %%
plt.scatter(df3.PetalLengthCm,df3.PetalWidthCm,marker = '*',color = 'red')
plt.scatter(df2.PetalLengthCm,df2.PetalWidthCm,marker = '.',color = 'green')

# %%
plt.scatter(df1.SepalLengthCm,df1.SepalWidthCm,marker = '+',color = 'blue')
plt.scatter(df2.SepalLengthCm,df2.SepalWidthCm,marker = '.',color = 'green')

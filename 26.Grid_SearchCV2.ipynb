# %%
import pandas as pd
from sklearn.datasets import load_digits

# %%
digit = load_digits()

# %%
dir(digit)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
X = digit.data
y = digit.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
classifiers = {
    
    'Logistic_Regression':{
        'model':LogisticRegression(),
        'param':{
            'C':[1,5,10,15,20]
        }
        
    },
     
    'Random_forest':{
        'model':RandomForestClassifier(),
        'param':{
            'n_estimators':[1,5,10,15,20,30,40]
        }
        
    },
    
    'svm':{
        'model': SVC(gamma='auto'),
        'param':{
            'C':[1,5,10,15,20],
            'kernel':['linear','rgb']
        }
        
    },
    
    
    
    
}

# %%
score = []
from sklearn.model_selection import GridSearchCV
for model_name,mp in classifiers.items():
    clf = GridSearchCV(mp['model'],mp['param'],cv = 5,return_train_score=False)
    clf.fit(X_train,y_train)
    score.append({
        'model':clf.best_estimator_,
        'best_score':clf.best_score_,
        'best_param':clf.best_params_
    })
    
clf.cv_results_
# Out:
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 226, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "C:\Users\apoor\anaconda3\lib\site-packages\sklearn\svm\_base.py", line 277, in _dense_fit
#     self._probB, self.fit_status_ = libsvm.fit(
#   File "sklearn\svm\_libsvm.pyx", line 176, in sklearn.svm._libsvm.fit
# ValueError: 'rgb' is not in list
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\apoor\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.97981514        nan 0.97981514        nan 0.97981514        nan
#  0.97981514        nan 0.97981514        nan]
#   warnings.warn(
# {'mean_fit_time': array([0.01458788, 0.00121446, 0.01700039, 0.00099888, 0.01612434,
#         0.0005218 , 0.01600766, 0.00101647, 0.01679287, 0.00039268]),
#  'std_fit_time': array([5.14489705e-04, 3.95966030e-04, 1.65681701e-03, 8.90371303e-06,
#         1.42735653e-03, 4.42159236e-04, 1.09443414e-03, 3.58128515e-05,
#         1.72348776e-03, 4.81048016e-04]),
#  'mean_score_time': array([0.00359602, 0.        , 0.00406666, 0.        , 0.00421023,
#         0.        , 0.00399032, 0.        , 0.00359774, 0.        ]),
#  'std_score_time': array([0.00046626, 0.        , 0.00097938, 0.        , 0.00075822,
#         0.        , 0.00063594, 0.        , 0.0007946 , 0.        ]),
#  'param_C': masked_array(data=[1, 1, 5, 5, 10, 10, 15, 15, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['linear', 'rgb', 'linear', 'rgb', 'linear', 'rgb',
#                     'linear', 'rgb', 'linear', 'rgb'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'rgb'},
#   {'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'rgb'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rgb'},
#   {'C': 15, 'kernel': 'linear'},
#   {'C': 15, 'kernel': 'rgb'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rgb'}],
#  'split0_test_score': array([0.97916667,        nan, 0.97916667,        nan, 0.97916667,
#                nan, 0.97916667,        nan, 0.97916667,        nan]),
#  'split1_test_score': array([0.98611111,        nan, 0.98611111,        nan, 0.98611111,
#                nan, 0.98611111,        nan, 0.98611111,        nan]),
#  'split2_test_score': array([0.97560976,        nan, 0.97560976,        nan, 0.97560976,
#                nan, 0.97560976,        nan, 0.97560976,        nan]),
#  'split3_test_score': array([0.97909408,        nan, 0.97909408,        nan, 0.97909408,
#                nan, 0.97909408,        nan, 0.97909408,        nan]),
#  'split4_test_score': array([0.97909408,        nan, 0.97909408,        nan, 0.97909408,
#                nan, 0.97909408,        nan, 0.97909408,        nan]),
#  'mean_test_score': array([0.97981514,        nan, 0.97981514,        nan, 0.97981514,
#                nan, 0.97981514,        nan, 0.97981514,        nan]),
#  'std_test_score': array([0.00342884,        nan, 0.00342884,        nan, 0.00342884,
#                nan, 0.00342884,        nan, 0.00342884,        nan]),
#  'rank_test_score': array([ 1,  6,  1,  7,  1,  8,  1,  9,  1, 10])}

# %%
df1 = pd.DataFrame(clf.cv_results_)
df1
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.014588      0.000514         0.003596        0.000466       1
# 1       0.001214      0.000396         0.000000        0.000000       1
# 2       0.017000      0.001657         0.004067        0.000979       5
# 3       0.000999      0.000009         0.000000        0.000000       5
# 4       0.016124      0.001427         0.004210        0.000758      10
# 5       0.000522      0.000442         0.000000        0.000000      10
# 6       0.016008      0.001094         0.003990        0.000636      15
# 7       0.001016      0.000036         0.000000        0.000000      15
# 8       0.016793      0.001723         0.003598        0.000795      20
# 9       0.000393      0.000481         0.000000        0.000000      20
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.979167
# 1          rgb      {'C': 1, 'kernel': 'rgb'}                NaN
# 2       linear   {'C': 5, 'kernel': 'linear'}           0.979167
# 3          rgb      {'C': 5, 'kernel': 'rgb'}                NaN
# 4       linear  {'C': 10, 'kernel': 'linear'}           0.979167
# 5          rgb     {'C': 10, 'kernel': 'rgb'}                NaN
# 6       linear  {'C': 15, 'kernel': 'linear'}           0.979167
# 7          rgb     {'C': 15, 'kernel': 'rgb'}                NaN
# 8       linear  {'C': 20, 'kernel': 'linear'}           0.979167
# 9          rgb     {'C': 20, 'kernel': 'rgb'}                NaN
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.986111            0.97561           0.979094           0.979094
# 1                NaN                NaN                NaN                NaN
# 2           0.986111            0.97561           0.979094           0.979094
# 3                NaN                NaN                NaN                NaN
# 4           0.986111            0.97561           0.979094           0.979094
# 5                NaN                NaN                NaN                NaN
# 6           0.986111            0.97561           0.979094           0.979094
# 7                NaN                NaN                NaN                NaN
# 8           0.986111            0.97561           0.979094           0.979094
# 9                NaN                NaN                NaN                NaN
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.979815        0.003429                1
# 1              NaN             NaN                6
# 2         0.979815        0.003429                1
# 3              NaN             NaN                7
# 4         0.979815        0.003429                1
# 5              NaN             NaN                8
# 6         0.979815        0.003429                1
# 7              NaN             NaN                9
# 8         0.979815        0.003429                1
# 9              NaN             NaN               10

# %%
score
# Out:
# [{'model': LogisticRegression(C=1),
#   'best_score': 0.9652076074332172,
#   'best_param': {'C': 1}},
#  {'model': RandomForestClassifier(n_estimators=30),
#   'best_score': 0.9728561749903214,
#   'best_param': {'n_estimators': 30}},
#  {'model': SVC(C=1, gamma='auto', kernel='linear'),
#   'best_score': 0.9798151374370885,
#   'best_param': {'C': 1, 'kernel': 'linear'}}]

# %%
df2 = pd.DataFrame(score)
df2
# Out:
#                                                model  best_score  \
# 0                            LogisticRegression(C=1)    0.965208
# 1  (DecisionTreeClassifier(max_features='auto', r...    0.972856
# 2            SVC(C=1, gamma='auto', kernel='linear')    0.979815
#
#                      best_param
# 0                      {'C': 1}
# 1          {'n_estimators': 30}
# 2  {'C': 1, 'kernel': 'linear'}
